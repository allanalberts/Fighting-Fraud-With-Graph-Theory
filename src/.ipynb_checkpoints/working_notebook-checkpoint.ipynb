# %% [markdown]
# # working notebook
#
# ### EDA Learnings:
# alpha network does not have time level timestamp so cannot do velocity or bot analysis
# or sort chronologically within a day
#
# ### Interesting Fraud Examples:
# alpha_user = '7483'
# otc_user = '2680'

# %%
import pandas as pd
import numpy as np
import datetime

import matplotlib.pyplot as plt
plt.style.use('ggplot')

import helpers as h
import visualizations as v

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 300)

# %%
# Load and preprocess data
otc_df = h.load_bitcoin_edge_data('../data/soc-sign-bitcoinotc.csv.gz')
alpha_df = h.load_bitcoin_edge_data('../data/soc-sign-bitcoinalpha.csv.gz')
alpha_users = h.user_activity_dataframe(alpha_df)
otc_users = h.user_activity_dataframe(otc_df)
alpha_G = h.load_bitcoin_graph(alpha_df)
oct_G = h.load_bitcoin_graph(otc_df, '2014-01-24')

# %%
v.plot_timeline(alpha, 'Alpha Bit Coin Ratings Activity')

# %%
v.plot_timeline(otc, 'OTC Bit Coin Ratings Activity')

# %%
def user_dashboard(bitcoin_df, exchange, user):
    print(f"User {user} Dashboard for bitcoin exchange {exchange}\n")
    print(bitcoin_df[(bitcoin_df['rater']==user) | (bitcoin_df['ratee']==user)].sort_values('date'),'\n')
    if exchange == 'alpha':
        print(alpha_users.loc[user])
    elif exchange == 'otc':
        print(otc_users.loc[user])
        
user_dashboard(alpha, 'alpha', '7483')
# Out:
# User 7483 Dashboard for bitcoin exchange alpha
#
# Empty DataFrame
# Columns: [rater, ratee, rating, date, class]
# Index: []
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '7483'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-78945b6679d4> in <module>
# ...

# %%
alpha.head()
# Out:
#   rater ratee  rating                date
# 0  7188     1      10 2014-08-07 21:00:00
# 1   430     1      10 2013-08-14 21:00:00
# 2  3134     1      10 2013-05-27 21:00:00
# 3  3026     1      10 2012-10-11 21:00:00
# 4  3010     1      10 2012-09-16 21:00:00

# %% [markdown]
# # Additions to Graph
# - color for edges that fraud
# - weighting??? or just fraud/nonfraud??
#
# - function to expand graph out one level

# %%
import networkx as nx
import nxpd
user = '7188'
df = alpha_df[['rater','ratee','rating']]

G = nx.DiGraph()
G.add_weighted_edges_from([tuple(x) for x in df[df['rater']==user].values])
G.add_weighted_edges_from([tuple(x) for x in df[df['ratee']==user].values])

# %%
G2 = nx.Graph(nx.ego_graph(G,'7188', radius=2))
# Out:
# ---------------------------------------------------------------------------
# NodeNotFound                              Traceback (most recent call last)
# <ipython-input-17-37a41c161a55> in <module>
# ----> 1 G2 = nx.Graph(nx.ego_graph(G,'7188', radius=2))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/networkx/generators/ego.py in ego_graph(G, n, radius, center, undirected, distance)
#      64                                               weight=distance)
#      65         else:
# ---> 66             sp = dict(nx.single_source_shortest_path_length(G, n, cutoff=radius))
#      67
#      68     H = G.subgraph(sp).copy()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/networkx/algorithms/shortest_paths/unweighted.py in single_source_shortest_path_length(G, source, cutoff)
#      60     """
#      61     if source not in G:
# ---> 62         raise nx.NodeNotFound('Source {} is not in G'.format(source))
#      63     if cutoff is None:
#      64         cutoff = float('inf')
#
# ...

# %%
# Connected_component_subgraphs() returns a list of components,
# sorted largest to smallest
components=nx.connected_component_subgraphs(G)
# pick the first and largest component
cc = components[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-ce81e74792d8> in <module>
#       3 components=nx.connected_component_subgraphs(G)
#       4 # pick the first and largest component
# ----> 5 cc = components[0]
#
# TypeError: 'generator' object is not subscriptable

# %%
print([tuple(x) for x in df[(df['ratee']==user) & (df['rating']<0)].values])
# Out:
# [('7', '7483', -10), ('22', '7483', -4), ('43', '7483', -10)]

# %%
def add_user(G, user):
    G.add_weighted_edges_from([tuple(x) for x in df[(df['rater']==user) & (df['rating']<0)].values],color='red')
    G.add_weighted_edges_from([tuple(x) for x in df[(df['rater']==user) & (df['rating']>0)].values])
    G.add_weighted_edges_from([tuple(x) for x in df[(df['ratee']==user) & (df['rating']<0)].values],color='red')
    G.add_weighted_edges_from([tuple(x) for x in df[(df['ratee']==user) & (df['rating']>0)].values])
    return G

# %%
def color_nodes(G, node_list, color):
    '''Add a filled color attribute to a list of graph nodes.'''
    for node in node_list:
        G.node[node]['style'] = 'filled'
        G.node[node]['fillcolor'] = color

# %%
# Draw left to right when possible, fits better in notebook
# is there a timeline here? When did the good gang decide to shut them all down?


G = nx.DiGraph()
G.graph['rankdir'] = 'LR'
G.add_node('7483', color='red', style='filled', fillcolor='pink')
G.add_node('7535', color='red', style='filled', fillcolor='pink')
G.add_node('7513', color='red', style='filled', fillcolor='pink')
G.add_node('7505', color='red', style='filled', fillcolor='pink')
G.add_node('7506', color='red', style='filled', fillcolor='pink')
G.add_node('7417', color='red', style='filled', fillcolor='pink')
G.add_node('7483', color='red', style='filled', fillcolor='pink')
G.add_node('7484', color='red', style='filled', fillcolor='pink')
G.add_node('7378', color='red', style='filled', fillcolor='pink')
G.add_weighted_edges_from([tuple(x) for x in df[(df['rater']==user) & (df['rating']<0)].values], color='red')
G.add_weighted_edges_from([tuple(x) for x in df[(df['rater']==user) & (df['rating']>0)].values])
G.add_weighted_edges_from([tuple(x) for x in df[(df['ratee']==user) & (df['rating']<0)].values], color='red')
G.add_weighted_edges_from([tuple(x) for x in df[(df['ratee']==user) & (df['rating']>0)].values])
G = add_user(G, '7513')
G = add_user(G, '7535')
G = add_user(G, '7505')
G = add_user(G, '7506')
G = add_user(G, '7378')
G = add_user(G, '7483')
G = add_user(G, '7484')
G = add_user(G, '7417')
G = add_user(G, '7378')
nxpd.draw(G, show='ipynb')

# %%
# make a symbol for a serious trader (> X trades)
# Out:
# ['7513', '7535', '7505']

# %%
fraud_node_lst = ['7505','7506', '7513','7535','7483','7485', '7378']
# how do you add ratings given out to neighbors (directed out neighbors)

# Neighbors who have been RATED by the user
print([n for n in G.neighbors('7483')])
print([[n for n in G['7483']]])
print([n for n in G.adj['7483']])
# Out:
# ['7513', '7535', '7505']
# [['7513', '7535', '7505']]
# ['7513', '7535', '7505']

# %%
from networkx.algorithms import community

communities_generator = community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)

sorted(map(sorted, top_level_communities))
# Out:
# [['22', '43', '7', '7483', '7505', '7535'], ['7513']]

# %% [markdown]
# The Girvan–Newman algorithm detects communities by progressively removing edges from the original graph. The algorithm removes the “most valuable” edge, traditionally the edge with the highest betweenness centrality, at each step. As the graph breaks down into pieces, the tightly knit community structure is exposed and the result can be depicted as a dendrogram.

# %%
import networkx.generators.small

g = networkx.generators.small.krackhardt_kite_graph()

g.adjacency_list()

# %%
color_map = []
for node in G:
    if node == user:
        color_map.append('lightgreen')
    else: 
        color_map.append('lightblue')      
nx.draw(G, node_color=color_map, with_labels=True)
plt.show()

# %%
# how can you be both a victim and a fraudster? Retalitory ratings??
alpha_users.groupby(['Victim','Fraudster'])['RatingsReceived'].count().reset_index()

# %%
otc_users[otc_users['BotActivity']==True].sort_values('TimeActive')

# %% [markdown]
# # Need to create visualization to Define Bot acitivity
# In Alpha network only bot activity is with zero time delay - all same day raters
# In OTC network only 18 users have zero time delay, however, XXX
# users have delay under 1? minute (what is delay )
#
# need 3 eda plots of same day rater distribution - day by hour, hour by minute, minute by second

# %%
print(f"Alpha Bot users: {alpha_users['BotActivity'].sum()}")
print(f"OTC Bot users: {otc_users['BotActivity'].sum()}")
